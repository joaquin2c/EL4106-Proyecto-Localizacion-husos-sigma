# %% [markdown]
# PRE-PROCESAMIENTO

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import time
# %load_ext tensorboard

#Cargamos los datos a trabajar

x_train_pre=np.load("./data/train_signals.npy")
y_train_pre=np.load("./data/train_marks.npy")
trainLen=len(x_train_pre)

x_val_pre=np.load("./data/val_signals.npy")
y_val_pre=np.load("./data/val_marks.npy")
valLen=len(x_val_pre)

x_test_pre=np.load("./data/test_signals.npy")
y_test_pre=np.load("./data/test_marks.npy")
testLen=len(x_test_pre)

#Creamos una funcion que muestree a un ratio deseado

def sampling(signals,samples,lenght,rate):
    x_new=[]
    for i in signals:
        x=[]
        for j in range(0,lenght,rate):
            x.append(i[j])
        x_new.append(x)
    return np.array(x_new)



#Creamos una funcion que clasifique con 1 o 0 los valores de la señal a trabajar

def oneHot(marks,lenght,rate):
    y_new=[]
    for i in marks:
        y=[]
        for j in range(0,lenght,rate):
            if(i[0]<=j & j<=i[1]):
                y.append(1)
            else:
                y.append(0)
        y_new.append(y)
    return np.array(y_new)

#Obtenemos los nuevos resultados de nuestras señales a trabajar

x_train1=sampling(x_train_pre,trainLen,800,1)
x_val1=sampling(x_val_pre,valLen,800,1)
x_test1=sampling(x_test_pre,testLen,800,1)

#Obtenemos los nuevos resultados de nuestras marcas a trabajar

y_train1=oneHot(y_train_pre,800,1)
y_val1=oneHot(y_val_pre,800,1)
y_test1=oneHot(y_test_pre,800,1)


#Función que crea fragmentos de la señal original, tomando como parametros la muestra, el tamaño del fragmento deseado
#y los pasos de un fragmento a otro

def finalInputs(X,windowsSize,steps):
    newX=[]
    lenght=X.shape[1]
    for chosen in X:
        for init in range(0,lenght-windowsSize+1,steps):
            newX.append(chosen[init:init+windowsSize])
    return np.array(newX)


#Función que toma un fragmento de la salida discretizada, la promedia y la clasifica en 1 o 0 según un umbral deseado 

def finalOutputs(Y,windowsSize,steps,theshold):
    newY=[]
    lenght=Y.shape[1]
    for chosen in Y:
        for init in range(0,lenght-windowsSize+1,steps):
            total=np.mean(chosen[init:init+windowsSize])
            if(total<=theshold):
                newY.append(0)
            else:
                newY.append(1)
            
    return np.array(newY)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
BATCH_SIZE=20
threshold=0.6
ventana=50
paso=3
#Se pre-procesan los datos con los valores deseados

x_trainf=finalInputs(x_train1,ventana,paso)
y_trainf=finalOutputs(y_train1,ventana,paso,threshold)

x_valX=finalInputs(x_val1,ventana,paso)
y_valX=finalOutputs(y_val1,ventana,paso,threshold)

x_valf=x_valX[0:10000]
y_valf=y_valX[0:10000]

x_testf=finalInputs(x_test1,ventana,paso)
y_testf=finalOutputs(y_test1,ventana,paso,threshold)

# %%
#Se procesas los datos para que no tenga problemas con el modelo

x_train=np.expand_dims(x_trainf,2)
y_train=tf.one_hot(y_trainf,2)


x_val=np.expand_dims(x_valf,2)
y_val=tf.one_hot(y_valf,2)

x_test=np.expand_dims(x_testf,2)
y_test=tf.one_hot(y_testf,2)

training_dataset = tf.data.Dataset.from_tensor_slices(
    (x_train, y_train)).batch(BATCH_SIZE)

test_dataset = tf.data.Dataset.from_tensor_slices(
    (x_test, y_test)).shuffle(buffer_size=1024).batch(BATCH_SIZE)

val_dataset = tf.data.Dataset.from_tensor_slices(
    (x_val, y_val)).shuffle(buffer_size=1024).batch(BATCH_SIZE)

#timexx=np.arange(0,800,1)

# %% [markdown]
# Creación del Modelo

# %%
#Se crea el modelo a usar
prob=0.5
model = tf.keras.Sequential()

for i in range(0,4):
    model.add(tf.keras.layers.Conv1D(40, 7, activation='elu',padding="same"))
    model.add(tf.keras.layers.Dropout(prob))
    model.add(tf.keras.layers.MaxPool1D(pool_size=5,strides=1,padding="same"))   

model.add(tf.keras.layers.LSTM(100,dropout=0.5))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(100, activation=tf.nn.relu, name='fc1'))
model.add(tf.keras.layers.Dropout(prob))

model.add(tf.keras.layers.Dense(2, activation=tf.nn.softmax, name='fc2'))

model.build(input_shape=(None,ventana,1))

model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 50, 40)            320
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 50, 40)            0
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 50, 40)            0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 50, 40)            11240
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 50, 40)            0
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 50, 40)            0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 50, 40)            11240
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 50, 40)            0
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 50, 40)            0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 50, 40)            11240
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 50, 40)            0
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 50, 40)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               56400
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 100)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 100)               10100
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 100)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 2)                 202
# =================================================================
# Total params: 100,742
# Trainable params: 100,742
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se compila el Modelo

# %%
model.fit(
    training_dataset, 
    epochs=10,
    steps_per_epoch=200,
    validation_data=val_dataset,
    validation_freq=1,
    callbacks=[tf.keras.callbacks.TensorBoard('./logs/trying_18', update_freq=10)]
)
# Out:
# Epoch 1/10
#   2/200 [..............................] - ETA: 4:52 - loss: 0.5041 - accuracy: 0.8250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0350s vs `on_train_batch_end` time: 2.9172s). Check your callbacks.
# 200/200 [==============================] - 15s 73ms/step - loss: 0.5383 - accuracy: 0.8062 - val_loss: 0.4731 - val_accuracy: 0.8229
# Epoch 2/10
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5333 - accuracy: 0.7987 - val_loss: 0.4523 - val_accuracy: 0.8229
# Epoch 3/10
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5575 - accuracy: 0.7850 - val_loss: 0.4641 - val_accuracy: 0.8229
# Epoch 4/10
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5793 - accuracy: 0.7617 - val_loss: 0.4598 - val_accuracy: 0.8229
# Epoch 5/10
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5234 - accuracy: 0.7997 - val_loss: 0.4484 - val_accuracy: 0.8229
# Epoch 6/10
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4845 - accuracy: 0.8160 - val_loss: 0.4673 - val_accuracy: 0.8229
# Epoch 7/10
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5121 - accuracy: 0.8062 - val_loss: 0.4323 - val_accuracy: 0.8229
# Epoch 8/10
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5046 - accuracy: 0.8108 - val_loss: 0.4462 - val_accuracy: 0.8229
# Epoch 9/10
# 200/200 [==============================] - 11s 55ms/step - loss: 0.4851 - accuracy: 0.8102 - val_loss: 0.4613 - val_accuracy: 0.8229
# Epoch 10/10
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5024 - accuracy: 0.7893 - val_loss: 0.4719 - val_accuracy: 0.8229

# %%
# %tensorboard --logdir=.
# Out:
# Reusing TensorBoard on port 6006 (pid 11472), started 21:04:15 ago. (Use '!kill 11472' to kill it.)
#       <iframe id="tensorboard-frame-8687c3785b7ca5a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8687c3785b7ca5a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# POST-PROCESAMIENTO

# %%
#Calcula las probabilidades de cada salida

def finalPredictionProba(X,model,windowsSize,steps):
    inputs=[]
    pred=[]
    lenght=len(X)
    for init in range(0,lenght-windowsSize+1,steps):
        newX=np.expand_dims(X[init:init+windowsSize],1)
        inputs.append(newX)
    inputs=np.array(inputs)
    output=model.predict(inputs)
    return output

#Clasifica las probabilidades según un umbral
def predictionOnes(Y,threshold):
    ans=[]
    for i in Y:
        if(i[1]>=threshold):
            ans.append(1)
        else:
            ans.append(0)
    return ans




#Calcula el rango de las salidas predichas
def rangeOnes(y):
    ones=[]
    lenght=len(y)
    for i in range(0,lenght):
        if(y[i]==1):
            ones.append(i)
    rang=[ones[0],ones[len(ones)-1]]
    
    return np.array(rang)

# Entrega rangos en los que se acumula un grupo de unos
def rangos(y):
    recuerdo=0
    actual=0
    inicio=0
    ones=[]
    lenght=len(y)
    for i in range(0,lenght):
        actual=y[i]
        if(recuerdo!=actual and actual==1):
            inicio=i
        elif(recuerdo!=actual and actual==0):
            final=i
            ones.append([inicio,final])
        recuerdo=actual
            
    if(ones==[]):
        return np.array([[0,1]])
    else:
        return np.array(ones)

# Calcula el tamaño de los rangos antes mencionados
def tamañosRangos(y):
    rang=rangos(y)
    tamaños=[]
    for i in rang:
        tamaños.append(i[1]-i[0])
    return tamaños

# Entrega un rango final de la zona predicha
def rangeOnes2(y):
    rang=rangos(y)
    tamaños=tamañosRangos(y)
    lenght=len(rang)
    maximo=max(tamaños)
    grupo=[]
    for i in range(0,lenght):
        if(tamaños[i]>=maximo/1.5):
            grupo.append(rang[i][0])
            grupo.append(rang[i][1])
            

    rang=[min(grupo),max(grupo)]
    return np.array(rang)
    

#Corrige el rango al tamaño original de la señal de entrada
def originalSize(rangeOf,Osize,Fsize):
    prop=Osize/Fsize
    ans=[]
    first=np.int(prop*rangeOf[0])
    second=np.int(prop*rangeOf[1])
    return np.array([first,second])     

#Entrega el rango predicho final, uniendo todas las funciones anteriores
def finalPrediction(X,model,windowsSize,steps,threshold):
    lenX=len(X)
    predictionProba=finalPredictionProba(X,model,windowsSize,steps)
    lenPred=len(predictionProba)
    predictOnes=predictionOnes(predictionProba,threshold)
    rangOnes=rangeOnes2(predictOnes)
    predictFinal=originalSize(rangOnes,lenX,lenPred)
    return predictFinal

#Entrega la salida predicha discretizada
def realOutput(rangeOf,size):
    output=[]
    for i in range(0,size):
        if(rangeOf[0]<=i and i<=rangeOf[1]):
            output.append(1)
        else:
            output.append(0)
    return output

# %%
#Calcula el IoU de una predicción
def IOU(x,y,model,windowsSize,steps,threshold):
    prediction=finalPrediction(x,model,windowsSize,steps,threshold)
    real=rangeOnes(y)
    prediction_init=prediction[0]
    prediction_final=prediction[1]
    real_init=real[0]
    real_final=real[1]
    if(real_init<prediction_init<real_final or real_init<prediction_final<real_final or 
       prediction_init<real_init<prediction_final or prediction_init<real_final<prediction_final):
        union=max(prediction_final,real_final)-min(prediction_init,real_init)
        overlap=min(prediction_final,real_final)-max(prediction_init,real_init)
        return max(0,overlap/union)
    else:
        return 0
   

#Calcula el IoU de un grupo de predicciónes
def allIOUfunct(x,y,model,windowsSize,steps,threshold):
    allIOU=[]
    lenght=len(y)
    for i in range(0,lenght):
        iou=IOU(x[i],y[i],model,windowsSize,steps,threshold)
        allIOU.append(iou)
    return allIOU
        
#Se plotea el IoU antes calculado en un histograma    
def plotIOU(list_iou,clases):
    plt.figure(figsize=(20,10))
    plt.hist(list_iou,clases,color="blue",ec="black")
    plt.title('IoU',fontsize=15)
    plt.ylabel('Cantidad de sucesos',fontsize=15)
    plt.xlabel('Tiempo',fontsize=15)

# %%
#Prepara para plotear los x
def areaX(rangeOf):
    area=[]
    first=np.int(np.round((rangeOf[0])))
    second=np.int(np.round(rangeOf[1]))
    for i in range(first,second):
        area.append(i)
    return np.array(area)

#Prepara para plotear los y
def areaY(rangeOf,size):
    area=[0]
    l=np.int(rangeOf[1]-rangeOf[0])
    for i in range(1,l-1):
        area.append(size)
    area.append(0)
    return np.array(area)

#Grafica zona predicha por el modelo
def graphPredicho(x,model,windowsSize,steps,threshold):
    predict=finalPrediction(x,model,windowsSize,steps,threshold)

    predAreaX=areaX(predict)
    predAreaY=areaY(predict,60)
    
    plt.figure(figsize=(20,10))
    plt.plot(x,'b')
    
    plt.plot(predAreaX,predAreaY,'r',label='Zona Predicha')
    plt.plot(predAreaX,-1*predAreaY,'r')
    
    plt.title('Localización del Huso Sigma',fontsize=15)
    plt.ylabel('Amplitud',fontsize=15)
    plt.xlabel('Tiempo',fontsize=15)
    plt.legend(loc="upper right",fontsize=15)
    plt.tick_params(labelsize=15)

#Grafica zona real    
def graphReal(x,y):
    realRange=rangeOnes(y)
    realAreaX=areaX(realRange)
    realAreaY=areaY(realRange,60)
    
    plt.figure(figsize=(20,10))
    plt.plot(x,'b')
    plt.plot(realAreaX,realAreaY,'g',label='Zona Real')
    plt.plot(realAreaX,-1*realAreaY,'g')

    
    plt.title('Localización del Huso Sigma',fontsize=15)
    plt.ylabel('Amplitud',fontsize=15)
    plt.xlabel('Tiempo',fontsize=15)
    plt.legend(loc="upper right",fontsize=15)
    plt.tick_params(labelsize=15)
    
#Grafica la señal, la area real donde hay un huso, y el area donde predice que ocurre
def graphFinal(x,y,model,windowsSize,steps,threshold):
    predict=finalPrediction(x,model,windowsSize,steps,threshold)

    predAreaX=areaX(predict)
    predAreaY=areaY(predict,60)
    
    realRange=rangeOnes(y)
    realAreaX=areaX(realRange)
    realAreaY=areaY(realRange,60)
    
    plt.figure(figsize=(20,10))
    plt.plot(x,'b')
    plt.plot(realAreaX,realAreaY,'g',label='Zona Real')
    plt.plot(realAreaX,-1*realAreaY,'g')
    
    plt.plot(predAreaX,predAreaY,'r',label='Zona Predicha')
    plt.plot(predAreaX,-1*predAreaY,'r')
    
    plt.title('Localización del Huso Sigma',fontsize=15)
    plt.ylabel('Amplitud',fontsize=15)
    plt.xlabel('Tiempo',fontsize=15)
    plt.legend(loc="upper right",fontsize=15)
    plt.tick_params(labelsize=15)

# %% [markdown]
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# VALOR A MODIFICAR POR USUARIO CON LAS MUESTRAS E HISTOGRAMAS DE ABAJO

# %%
Umbral_de_clasificación=0.27
graphFinal(x_test1[10],y_test1[10],model,ventana,paso,Umbral_de_clasificación)

# %%
graphFinal(x_val1[1],y_val1[1],model,ventana,paso,Umbral_de_clasificación)

# %%
grapPredicho(x_val1[1],model,ventana,paso,Umbral_de_clasificación)

# %%
graphReal(x_val1[1],y_val1[1])

# %%
x_val1XXX=x_val1[0:60]
y_val1XXX=y_val1[0:60]
datoss=allIOUfunct(x_val1XXX,y_val1XXX,model,ventana,paso,Umbral_de_clasificación)
plotIOU(datoss,15)

# %%
#Histograma del IoU de los datos de validación
finalDatos=allIOUfunct(x_val1,y_val1,model,ventana,paso,Umbral_de_clasificación)
plotIOU(finalDatos,15)

# %%
##Promedio y desviación estandar del IoU de los datos de validación
meanVal=np.mean(finalDatos)
stdVal=np.std(finalDatos)
print(meanVal)
print(stdVal)
# Out:
# 0.5612930214383947
# 0.2280301584915408

# %%
#Histograma del IoU de los datos de entrenamiento
finalDatos2=allIOUfunct(x_test1,y_test1,model,ventana,paso,Umbral_de_clasificación)
plotIOU(finalDatos2,15)

# %%
##Promedio y desviación estandar del IoU de los datos de entrenamiento
meanVal2=np.mean(finalDatos2)
stdVal2=np.std(finalDatos2)
print(meanVal2)
print(stdVal2)
# Out:
# 0.597082757919469
# 0.23921896057329486

# %%
##Muestra que mejor se clasifican
maximoDato=0
maximoPos=0
large=len(finalDatos)
for i in range(0,large):
    if(finalDatos[i]>maximoDato):
        maximoDato=finalDatos[i]
        maximaPos=i
# Out:
# 1778

# %%
graphFinal(x_val1[maximaPos],y_val1[maximaPos],model,ventana,paso,Umbral_de_clasificación)

# %%
##Muestra que peor se claifican
minimoDato=1
minimoPos=0
large=len(finalDatos)
for i in range(0,large):
    if(finalDatos[i]<minimoDato):
        minimoDato=finalDatos[i]
        minimoPos=i
# Out:
# 402968

# %%
graphFinal(x_val1[minimoPos],y_val1[minimoPos],model,ventana,paso,Umbral_de_clasificación)
